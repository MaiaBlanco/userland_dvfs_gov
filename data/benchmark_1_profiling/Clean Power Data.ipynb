# %%
import pandas as pd
fname = "thermal_ondemand_60c_rr_bench.csv"

# %%
data = pd.read_csv(fname, sep='\t', header=0, index_col=False)

# %%
data.head()
# Out:
#            time  watts    w_leak     w_dyn  w_periph  usage_c0  usage_c1  \
# 0  1.513316e+09  0.000  0.261928 -2.515928     2.254  0.428571       0.0
# 1  1.513316e+09  2.561  0.261928  0.045072     2.254  0.166667       0.0
# 2  1.513316e+09  2.645  0.263635  0.127365     2.254  0.000000       0.0
# 3  1.513316e+09  2.645  0.262319  0.128681     2.254  0.333333       0.0
# 4  1.513316e+09  2.653  0.262319  0.136681     2.254  0.000000       0.0
#
#    usage_c2  usage_c3  usage_c4    ...      temp7  temp_gpu  \
# 0       0.0       0.0  0.000000    ...       50.0      48.0
# 1       0.0       0.0  0.000000    ...       50.0      48.0
# 2       0.0       0.0  0.000000    ...       50.0      48.0
# 3       0.0       0.0  0.333333    ...       50.0      48.0
# 4       0.0       0.0  0.333333    ...       50.0      48.0
#
#    freq_little_cluster  freq_big_cluster     freq_gpu     freq_mem  \
# 0          200000000.0       600000000.0  600000000.0  825000000.0
# ...

# %%
data2 = data.loc[data.watts != 0.0]

# %%
data3 = data2.iloc[10260:]
# data3.head(200)

# %%
data3.to_csv("cleaned_"+fname, sep='\t')
